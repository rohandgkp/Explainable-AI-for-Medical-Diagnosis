jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/meningioma/Te-me_0051.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/meningioma/Te-me_0057.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/meningioma/Te-me_0020.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/meningioma/Te-me_0134.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/meningioma/Te-me_0031.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/meningioma/Te-me_0151.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/meningioma/Te-me_0124.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0066.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0043.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0048.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0028.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0146.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0061.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0132.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0151.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0071.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0044.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0015.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0117.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0027.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0079.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0046.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0074.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0128.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0085.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0073.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0016.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0039.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0059.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0072.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0153.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0078.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0126.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0118.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0034.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0080.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0018.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0033.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0106.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0144.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0150.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0130.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0064.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0125.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0099.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0019.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0120.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0020.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0050.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0113.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0062.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0056.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0014.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0110.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0031.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0096.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0038.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0023.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0010.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0097.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0100.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0114.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0035.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0123.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0049.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0091.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0092.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0087.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0075.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0063.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0030.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0139.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0138.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0026.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0052.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0121.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0109.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0070.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0136.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0017.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0083.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0133.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0141.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0104.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0022.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0069.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0131.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0149.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0057.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0116.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0025.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0135.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0053.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0105.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0115.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0137.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0058.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0145.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0047.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0086.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0011.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0024.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0067.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0140.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0148.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0094.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0012.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0021.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0041.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0112.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0084.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0093.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0060.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0102.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0143.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0077.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0068.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0042.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0124.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0152.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0103.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0054.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0134.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0051.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0122.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0045.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0055.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0127.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0098.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0082.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0037.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0029.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0119.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0032.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0090.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0013.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0095.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0036.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0129.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0065.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0081.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0101.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0076.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0147.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0111.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0040.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0088.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0089.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0142.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0107.jpg
# /kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/glioma/Te-gl_0108.jpg

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Flatten, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import os

# %%
train_dir = "/kaggle/input/brain-tumor-mris/brain_tumor_mris/Training"
val_dir = "/kaggle/input/brain-tumor-mris/brain_tumor_mris/Validation"
test_dir = "/kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing"

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
# Get the class names (folder names)
class_names = sorted(os.listdir(train_dir))
print("Classes:", class_names)

# Dictionary to store one image path from each class
image_paths = {class_name: os.path.join(train_dir, class_name, os.listdir(os.path.join(train_dir, class_name))[0])
               for class_name in class_names}
# Out:
# Classes: ['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
fig, axes = plt.subplots(1, len(class_names), figsize=(15, 5))

for ax, (class_name, image_path) in zip(axes, image_paths.items()):
    img = load_img(image_path, target_size=(224, 224))  # Load image
    ax.imshow(img)
    ax.set_title(class_name)
    ax.axis("off")  # Hide axis

plt.show()

# %% [markdown]
# **Data Augmentation**

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
img_height = 224
img_width = 224
batch_size = 32

# %%
img_size = (img_height, img_width)

# %%
import keras
data_augmentation = keras.Sequential(
[
    layers.RandomFlip("horizontal",
                     input_shape=(img_height,
                                 img_width,
                                  3)),

    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1)
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Data Augmentation for Training Data
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal", input_shape=(img_height, img_width, 3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1)
])

# Training Data Generator with Augmentation
train_datagen = ImageDataGenerator(
    rescale=1.0/255,  # Normalize pixel values
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True
)

# Validation & Testing Data Generators (Only Rescaling)
val_test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load Training Images
train_generator = train_datagen.flow_from_directory(
    train_dir, target_size=(img_height, img_width), batch_size=batch_size, class_mode='categorical'
)

# Load Validation Images
val_generator = val_test_datagen.flow_from_directory(
    val_dir, target_size=(img_height, img_width), batch_size=batch_size, class_mode='categorical'
)

# Load Testing Images (Without Shuffling for Consistent Predictions)
test_generator = val_test_datagen.flow_from_directory(
    test_dir, target_size=(img_height, img_width), batch_size=batch_size, class_mode='categorical', shuffle=False
)
# Out:
# Found 4672 images belonging to 4 classes.
# Found 576 images belonging to 4 classes.
# Found 576 images belonging to 4 classes.

# %%
# Get class names
class_names = list(train_generator.class_indices.keys())
print("Classes:", class_names)

# Initialize plot
fig, axes = plt.subplots(1, len(class_names), figsize=(15, 5))

# Dictionary to store one augmented image per class
displayed_classes = set()

# Iterate through the dataset to find one image per class
for images, labels in train_generator:
    for i in range(len(labels)):
        class_index = np.argmax(labels[i])  # Get class index
        class_name = class_names[class_index]

        if class_name not in displayed_classes:
            # Apply augmentation
            augmented_img = data_augmentation(tf.expand_dims(images[i], axis=0))

            # Display image
            axes[len(displayed_classes)].imshow(augmented_img[0])
            axes[len(displayed_classes)].set_title(class_name)
            axes[len(displayed_classes)].axis("off")

            displayed_classes.add(class_name)

        if len(displayed_classes) == len(class_names):  # Stop when all classes are covered
            break
    if len(displayed_classes) == len(class_names):
        break

plt.tight_layout()
plt.show()
# Out:
# Classes: ['glioma', 'meningioma', 'notumor', 'pituitary']

# %% [markdown]
# **Fine-tuning**

# %%
import tensorflow as tf
from tensorflow.keras import layers, regularizers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %%
# Load the previously trained model
model = tf.keras.models.load_model('/kaggle/input/customcnn2/keras/default/1/best_model2.keras')

# %%
# Freeze the first few layers to retain previously learned features
for layer in model.layers[:10]:  # Freeze first 10 layers
    layer.trainable = False

# %%
# Set a lower learning rate for fine-tuning
fine_tune_lr = 1e-5

# %%
# Compile the model with a lower learning rate
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=fine_tune_lr),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Define EarlyStopping (Allow more patience since fine-tuning needs time)
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=15,  # Increased patience
    restore_best_weights=True,
    verbose=1
)

# ModelCheckpoint (Save best fine-tuned model)
model_checkpoint = ModelCheckpoint(
    filepath='fine_tuned_model2.keras',
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)

# ReduceLROnPlateau (Reduce LR if val_loss stops improving)
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,  # Reduce LR by half
    patience=7,  # Wait longer before reducing LR
    min_lr=1e-7,  # Lower limit for LR
    verbose=1
)

# %%
# Fine-tune the model
history = model.fit(
    train_generator,
    epochs=100,  # Fewer epochs for fine-tuning
    validation_data=val_generator,
    callbacks=[early_stopping, model_checkpoint, reduce_lr]
)
# Out:
# Epoch 1/100
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 574ms/step - accuracy: 0.9934 - loss: 0.1536
# Epoch 1: val_loss improved from inf to 0.42401, saving model to fine_tuned_model2.keras
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 101s 666ms/step - accuracy: 0.9934 - loss: 0.1536 - val_accuracy: 0.9201 - val_loss: 0.4240 - learning_rate: 1.0000e-05
# Epoch 2/100
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - accuracy: 0.9957 - loss: 0.1320
# Epoch 2: val_loss improved from 0.42401 to 0.37157, saving model to fine_tuned_model2.keras
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 66s 430ms/step - accuracy: 0.9957 - loss: 0.1320 - val_accuracy: 0.9462 - val_loss: 0.3716 - learning_rate: 1.0000e-05
# Epoch 3/100
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.9954 - loss: 0.1202
# Epoch 3: val_loss improved from 0.37157 to 0.35182, saving model to fine_tuned_model2.keras
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 65s 428ms/step - accuracy: 0.9954 - loss: 0.1202 - val_accuracy: 0.9479 - val_loss: 0.3518 - learning_rate: 1.0000e-05
# Epoch 4/100
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.9947 - loss: 0.1176
# Epoch 4: val_loss did not improve from 0.35182
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 61s 399ms/step - accuracy: 0.9947 - loss: 0.1176 - val_accuracy: 0.9236 - val_loss: 0.4098 - learning_rate: 1.0000e-05
# Epoch 5/100
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.9956 - loss: 0.1139
# Epoch 5: val_loss did not improve from 0.35182
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 61s 399ms/step - accuracy: 0.9956 - loss: 0.1139 - val_accuracy: 0.9427 - val_loss: 0.3584 - learning_rate: 1.0000e-05
# Epoch 6/100
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.9959 - loss: 0.1069
# Epoch 6: val_loss did not improve from 0.35182
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 62s 404ms/step - accuracy: 0.9959 - loss: 0.1069 - val_accuracy: 0.9340 - val_loss: 0.3871 - learning_rate: 1.0000e-05
# Epoch 7/100
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.9973 - loss: 0.1004
# Epoch 7: val_loss did not improve from 0.35182
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 62s 406ms/step - accuracy: 0.9973 - loss: 0.1004 - val_accuracy: 0.9340 - val_loss: 0.3873 - learning_rate: 1.0000e-05
# Epoch 8/100
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - accuracy: 0.9969 - loss: 0.1016
# Epoch 8: val_loss did not improve from 0.35182
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 62s 402ms/step - accuracy: 0.9969 - loss: 0.1016 - val_accuracy: 0.9340 - val_loss: 0.3839 - learning_rate: 1.0000e-05
# Epoch 9/100
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.9972 - loss: 0.0970
# Epoch 9: val_loss did not improve from 0.35182
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 62s 401ms/step - accuracy: 0.9972 - loss: 0.0970 - val_accuracy: 0.9306 - val_loss: 0.4023 - learning_rate: 1.0000e-05
# Epoch 10/100
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.9952 - loss: 0.1002
# Epoch 10: val_loss did not improve from 0.35182
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 62s 404ms/step - accuracy: 0.9952 - loss: 0.1002 - val_accuracy: 0.9340 - val_loss: 0.3926 - learning_rate: 1.0000e-05
# Epoch 11/100
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.9967 - loss: 0.0969
# Epoch 11: val_loss did not improve from 0.35182
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 61s 401ms/step - accuracy: 0.9967 - loss: 0.0969 - val_accuracy: 0.9288 - val_loss: 0.4128 - learning_rate: 5.0000e-06
# Epoch 12/100
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.9971 - loss: 0.0977
# Epoch 12: val_loss did not improve from 0.35182
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 61s 398ms/step - accuracy: 0.9971 - loss: 0.0977 - val_accuracy: 0.9236 - val_loss: 0.4422 - learning_rate: 5.0000e-06
# Epoch 13/100
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.9971 - loss: 0.0930
# Epoch 13: val_loss did not improve from 0.35182
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 60s 394ms/step - accuracy: 0.9971 - loss: 0.0930 - val_accuracy: 0.9271 - val_loss: 0.4168 - learning_rate: 5.0000e-06
# Epoch 14/100
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.9961 - loss: 0.0943
# Epoch 14: val_loss did not improve from 0.35182
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 60s 391ms/step - accuracy: 0.9961 - loss: 0.0943 - val_accuracy: 0.9271 - val_loss: 0.4304 - learning_rate: 5.0000e-06
# Epoch 15/100
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.9961 - loss: 0.0954
# Epoch 15: val_loss did not improve from 0.35182
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 60s 393ms/step - accuracy: 0.9962 - loss: 0.0954 - val_accuracy: 0.9236 - val_loss: 0.4297 - learning_rate: 5.0000e-06
# Epoch 16/100
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.9967 - loss: 0.0921
# Epoch 16: val_loss did not improve from 0.35182
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 61s 394ms/step - accuracy: 0.9967 - loss: 0.0921 - val_accuracy: 0.9323 - val_loss: 0.4211 - learning_rate: 5.0000e-06
# Epoch 17/100
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.9956 - loss: 0.0921
# Epoch 17: val_loss did not improve from 0.35182
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 61s 395ms/step - accuracy: 0.9956 - loss: 0.0921 - val_accuracy: 0.9288 - val_loss: 0.4246 - learning_rate: 5.0000e-06
# Epoch 18/100
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.9975 - loss: 0.0907
# Epoch 18: val_loss did not improve from 0.35182
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 61s 397ms/step - accuracy: 0.9975 - loss: 0.0907 - val_accuracy: 0.9271 - val_loss: 0.4187 - learning_rate: 2.5000e-06
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 3.

# %%
import matplotlib.pyplot as plt

# Extract training and validation metrics
acc = [a * 100 for a in history.history['accuracy']]
val_acc = [a * 100 for a in history.history['val_accuracy']]
loss = [b * 100 for b in history.history['loss']]
val_loss = [b * 100 for b in history.history['val_loss']]
epochs_range = range(len(acc))

# Plot Training & Validation Accuracy
plt.figure(figsize=(5, 5))
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
#plt.title("Training & Validation Accuracy")
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.ylim([0, 105])  # Ensure values stay within range
#plt.grid(True, linestyle='--', alpha=0.5)  # Add grid lines for better visualization
plt.savefig('Fine-Tuned_Custom2_200_training_validation_accuracy.png')
plt.show()

# Plot Training & Validation Loss
plt.figure(figsize=(5, 5))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
#plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss (%)')
plt.ylim([0, 250])
#plt.grid(True, linestyle='--', alpha=0.5)
plt.savefig('Fine-Tuned_Custom2_200_training_validation_loss.png')
plt.show()

# %%
model.evaluate(train_generator) # Training accuracy and loss
# Out:
# 146/146 ━━━━━━━━━━━━━━━━━━━━ 58s 397ms/step - accuracy: 0.9989 - loss: 0.1084
# [0.10842828452587128, 0.9989297986030579]

# %%
model.evaluate(val_generator) # Validation accuracy and loss
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - accuracy: 0.9517 - loss: 0.2973
# [0.3518218398094177, 0.9479166865348816]

# %%
model.evaluate(test_generator) # Testing accuracy and loss
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 294ms/step - accuracy: 0.9922 - loss: 0.1327
# [0.13188855350017548, 0.9930555820465088]

# %%
num_classes = 4

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# Get true labels and one-hot encode them
y_true = test_generator.classes  # True labels from test set
y_true_binarized = label_binarize(y_true, classes=np.arange(num_classes))

# Predict probabilities in one step (faster execution)
y_pred_probs = model.predict(test_generator, verbose=0)

# Create figure for ROC curves
plt.figure(figsize=(7, 7))

# Compute and plot ROC curve for each class
for i in range(num_classes):
    fpr, tpr, _ = roc_curve(y_true_binarized[:, i], y_pred_probs[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'{class_names[i]} (AUROC = {roc_auc:.20f})')

# Formatting
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
#plt.grid(True, linestyle='--', alpha=0.6)

# Save and display the AUROC plot
plt.savefig('Fine-Tuned_Custom2_AUROC.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import numpy as np

# Get true labels and one-hot encode them
y_true = test_generator.classes  # True labels from test set
y_true_binarized = label_binarize(y_true, classes=np.arange(num_classes))

# Predict probabilities
y_pred_probs = model.predict(test_generator, verbose=0)

# Compute AUROC for each class
auroc_values = []
for i in range(num_classes):
    fpr, tpr, _ = roc_curve(y_true_binarized[:, i], y_pred_probs[:, i])
    roc_auc = auc(fpr, tpr)  # Compute AUROC
    auroc_values.append(roc_auc)

# Print exact AUROC values (no rounding)
print("AUROC values for each class:", auroc_values)
# Out:
# AUROC values for each class: [0.9999839248971194, 0.9995498971193416, 1.0, 0.9999999999999999]

# %% [markdown]
# **Prediction**

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
import os

# Select an image from the testing set
test_image_path = "/kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/pituitary/Te-pi_0033.jpg"  # Change this to any test image path

# Load and preprocess the image
img = image.load_img(test_image_path, target_size=(224, 224))  # Resize to ResNet50 input size
img_array = image.img_to_array(img)  # Convert to NumPy array
img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
img_array = img_array / 255.0  # Normalize (if preprocessing requires)

# Make prediction
pred_probs = model.predict(img_array)
pred_class = np.argmax(pred_probs, axis=1)[0]  # Get the class index

# Get class label
pred_class_name = class_names[pred_class]  # Assuming class_names contains the actual labels

# Display image with prediction
plt.imshow(img)
plt.axis("off")
plt.title(f"Predicted: {pred_class_name} (Confidence: {pred_probs[0][pred_class]:.2f})")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
from sklearn.metrics import classification_report, confusion_matrix

# y_true is already in label format, so don't apply argmax
y_true_classes = y_true  # No need for np.argmax
y_pred_classes = np.argmax(y_pred_probs, axis=1)  # Convert probabilities to class labels

# Generate classification report and confusion matrix
print(classification_report(y_true_classes, y_pred_classes, target_names=class_names))
print(confusion_matrix(y_true_classes, y_pred_classes))
# Out:
#               precision    recall  f1-score   support
#
#       glioma       1.00      0.99      1.00       144
#   meningioma       1.00      0.98      0.99       144
#      notumor       0.98      1.00      0.99       144
#    pituitary       0.99      1.00      1.00       144
#
#     accuracy                           0.99       576
#    macro avg       0.99      0.99      0.99       576
# weighted avg       0.99      0.99      0.99       576
#
# [[143   0   0   1]
#  [  0 141   3   0]
#  [  0   0 144   0]
#  [  0   0   0 144]]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Compute confusion matrix
cm = confusion_matrix(y_true, np.argmax(y_pred_probs, axis=1))

# Define class names (Modify as per your dataset)
class_names = ['Glioma', 'Meningioma', 'No Tumor', 'Pituitary']

# Plot confusion matrix
plt.figure(figsize=(7, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)

# Formatting
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
#plt.title('Confusion Matrix')

# Save the confusion matrix as an image
plt.savefig('Fine-Tuned_Custom2_200_confusion_matrix.png', dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 112, 112, 64)        │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 112, 112, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 112, 112, 128)       │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 56, 56, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 56, 56, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 28, 28, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 28, 28, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 14, 14, 512)         │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 100352)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │      51,380,736 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 4)                   │           1,028 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 166,311,502 (634.43 MB)
#  Trainable params: 55,054,596 (210.02 MB)
#  Non-trainable params: 1,147,712 (4.38 MB)
#  Optimizer params: 110,109,194 (420.03 MB)

# %% [markdown]
# **Explainable AI**

# %% [markdown]
# **Occlusion Sensitivity**

# %%
IMG_SIZE = (224, 224)

# %%
def occlusion_sensitivity(img_path, model, patch_size=20):
    img = keras.preprocessing.image.load_img(img_path, target_size=IMG_SIZE)
    img_array = keras.preprocessing.image.img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)

    occlusion_map = np.zeros_like(img_array[0, :, :, 0])

    for i in range(0, IMG_SIZE[0], patch_size):
        for j in range(0, IMG_SIZE[1], patch_size):
            occluded_img = img_array.copy()
            occluded_img[0, i:i+patch_size, j:j+patch_size, :] = 0

            prediction = model.predict(occluded_img)
            class_idx = np.argmax(prediction[0])

            occlusion_map[i:i+patch_size, j:j+patch_size] = prediction[0][class_idx]

    plt.imshow(img)
    plt.imshow(occlusion_map, cmap='jet', alpha=0.3)
    plt.show()

# Run Occlusion Sensitivity
occlusion_sensitivity("/kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/pituitary/Te-pi_0011.jpg", model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %% [markdown]
# **LIME**

# %%
from lime import lime_image

def explain_lime(img_path, model):
    img = keras.preprocessing.image.load_img(img_path, target_size=IMG_SIZE)
    img_array = keras.preprocessing.image.img_to_array(img) / 255.0

    explainer = lime_image.LimeImageExplainer()
    explanation = explainer.explain_instance(
        img_array.astype('double'),
        model.predict,
        top_labels=5,
        hide_color=0,
        num_samples=1000
    )

    temp, mask = explanation.get_image_and_mask(
        explanation.top_labels[0], positive_only=True, num_features=5, hide_rest=True
    )

    plt.imshow(temp)
    plt.imshow(mask, alpha=0.1)
    plt.show()

explain_lime("/kaggle/input/brain-tumor-mris/brain_tumor_mris/Testing/meningioma/Te-me_0036.jpg", model)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
